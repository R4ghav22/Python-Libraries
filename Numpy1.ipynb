# %%
import numpy as np
array=[2,3,4,5,6]
type(array)
# Out:
# list

# %% [markdown]
# # Creating 1D Array

# %%
arr=np.array([2,4,5,6,7])
arr
# Out:
# array([2, 4, 5, 6, 7])

# %%
type(arr)
# Out:
# numpy.ndarray

# %% [markdown]
# # Creating a 2D Array

# %%
arr_2d=np.array([ [1,2,3] , [4,5,6] , [3,9,2] ])
arr_2d
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [3, 9, 2]])

# %%
arr_2d.shape
# Out:
# (3, 3)

# %%
arr.shape
# Out:
# (5,)

# %% [markdown]
# # Creating an array of zeroes

# %%
arrz=np.zeros([2,3])
#type(arrz) -> numpy.ndarray
#arrz.dtype->dtype('float64')
arrz=arrz.astype(int)
arrz
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %% [markdown]
# # Creating an array of ones

# %%
arr_ones=np.ones([3,3] , dtype=int)
#arr_ones=arr_ones.astype(int)
arr_ones
# Out:
# array([[1, 1, 1],
#        [1, 1, 1],
#        [1, 1, 1]])

# %% [markdown]
# # Creating an Array with a Specific Value

# %%
filler_arr=np.full((2,4) , 67)
filler_arr
# Out:
# array([[67, 67, 67, 67],
#        [67, 67, 67, 67]])

# %% [markdown]
# # Sequence of numbers

# %%
seq_array=np.arange(0,100,20)  #100 is excluded like for loops in python
seq_array
# Out:
# array([ 0, 20, 40, 60, 80])

# %% [markdown]
# # line Space in Array

# %%
line_arr=np.linspace(1,100,5)  # 100 is included here by default.
line_arr
# Out:
# array([  1.  ,  25.75,  50.5 ,  75.25, 100.  ])

# %% [markdown]
# # Generating Random Arrays

# %%
rand_array=np.random.rand(2,3)  #[0,1)
rand_array
# Out:
# array([[0.62666707, 0.69624301, 0.42864062],
#        [0.24369276, 0.78396053, 0.13615704]])

# %%
rand_array2=np.random.randint(55 , 100 , (3,4) )
rand_array2
# Out:
# array([[94, 68, 60, 89],
#        [69, 99, 56, 99],
#        [74, 65, 94, 88]], dtype=int32)

# %%
#Function	                     Start	     End
''' np.arange(0,100,20)      	Included	Excluded
    np.random.randint(55,100)	Included	Excluded
    np.linspace(10,100,6)	    Included	Included '''
