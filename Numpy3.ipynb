# %%
import numpy as np

# %% [markdown]
# # Indexing in a 2D Array

# %%
a1 = np.array([[10,20,30], [21,31,41]])
a1[1,2]
# Out:
# np.int64(41)

# %%
a1[0,1]
# Out:
# np.int64(20)

# %%
a1[0][1]
# Out:
# np.int64(20)

# %% [markdown]
# # Getting a row

# %%
a1[0]
# Out:
# array([10, 20, 30])

# %%
a1[0 ,:]
# Out:
# array([10, 20, 30])

# %% [markdown]
# # Getting a column

# %%
a1[: , 0]
# Out:
# array([10, 21])

# %%
a1[: , 1]
# Out:
# array([20, 31])

# %% [markdown]
# # Array Splitting

# %%
a2=np.array([4,0,6,3,8,1])
a2.size
# Out:
# 6

# %%
y=np.split(a2 , 3)
y
# Out:
# [array([4, 0]), array([6, 3]), array([8, 1])]

# %%
np.split(a2 , 6)
# Out:
# [array([4]), array([0]), array([6]), array([3]), array([8]), array([1])]

# %%
a2
# Out:
# array([4, 0, 6, 3, 8, 1])

# %% [markdown]
# # Math operations on Arrays

# %%
a3=([1,2,3,4,5])
a4=np.square(a3)
a4
# Out:
# array([ 1,  4,  9, 16, 25])

# %%
np.square(a3)
# Out:
# array([ 1,  4,  9, 16, 25])

# %%
a3
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # Aggregate functions

# %%
a5=np.array([4,5,2,9,8])
a5
# Out:
# array([4, 5, 2, 9, 8])

# %%
s=np.sum(a5)
s
# Out:
# np.int64(28)

# %%
k=np.prod(a5)
k
# Out:
# np.int64(2880)

# %%
np.mean(a5)
# Out:
# np.float64(5.6)

# %%
np.max(a5)
# Out:
# np.int64(9)

# %%
np.median(a5)
# Out:
# np.float64(5.0)

# %%
a5
# Out:
# array([4, 5, 2, 9, 8])

# %%
std_dev=np.std(a5)
std_dev
# Out:
# np.float64(2.5768197453450252)

# %% [markdown]
# # Array Sorting in Numpy

# %%
a6=np.array([15,61,2,89,56,230])
a6
# Out:
# array([ 15,  61,   2,  89,  56, 230])

# %%
np.sort(a6)
# Out:
# array([  2,  15,  56,  61,  89, 230])

# %%
a6
# Out:
# array([ 15,  61,   2,  89,  56, 230])

# %% [markdown]
# # Array Searching

# %%
a6
# Out:
# array([ 15,  61,   2,  89,  56, 230])

# %%
key=np.where(a6==61)
key
# Out:
# (array([1]),)

# %%
key2=np.where(a6==230)
key2
# Out:
# (array([5]),)
