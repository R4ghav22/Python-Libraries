# %%
import pandas as pd

# %%
data=pd.read_excel('ECOMM DATA.xlsx')
data
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
# 51290    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
data
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
# 51290    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51291 entries, 0 to 51290
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51291 non-null  int64
#  1   Order ID        51291 non-null  object
#  2   Order Date      51291 non-null  datetime64[ns]
#  3   Ship Date       51291 non-null  datetime64[ns]
#  4   Ship Mode       51291 non-null  object
#  5   Customer ID     51291 non-null  object
#  6   Customer Name   51291 non-null  object
#  7   Segment         51291 non-null  object
#  8   City            51291 non-null  object
#  9   State           51291 non-null  object
#  10  Country         51291 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51291 non-null  object
#  13  Region          51291 non-null  object
#  14  Product ID      51291 non-null  object
#  15  Category        51291 non-null  object
# ...

# %%
data.isnull()
# Out:
#        Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0       False     False       False      False      False        False
# 1       False     False       False      False      False        False
# 2       False     False       False      False      False        False
# 3       False     False       False      False      False        False
# 4       False     False       False      False      False        False
# ...       ...       ...         ...        ...        ...          ...
# 51286   False     False       False      False      False        False
# 51287   False     False       False      False      False        False
# 51288   False     False       False      False      False        False
# 51289   False     False       False      False      False        False
# 51290   False     False       False      False      False        False
#
#        Customer Name  Segment   City  State  Country  Postal Code  Market  \
# ...

# %%
data.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41297
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
data['Row ID'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# 51290    False
# Name: Row ID, Length: 51291, dtype: bool

# %%
data['Row ID']
# Out:
# 0        32298
# 1        26341
# 2        25330
# 3        13524
# 4        47221
#          ...
# 51286    35398
# 51287    40470
# 51288     9596
# 51289     6147
# 51290     6147
# Name: Row ID, Length: 51291, dtype: int64

# %%
data['Row ID'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Postal Code'].isnull().sum()
# Out:
# np.int64(41297)

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# 51290     True
# Length: 51291, dtype: bool

# %%
data['Row ID'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# 51290     True
# Name: Row ID, Length: 51291, dtype: bool

# %%
data['Row ID'].duplicated().sum()
# Out:
# np.int64(1)

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %%
data[data['Row ID']>10000]
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51283   24105    IN-2014-72327 2014-05-30 2014-05-30        Same Day
# 51284   24175    IN-2014-57662 2014-08-05 2014-08-10  Standard Class
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
#
#       Customer ID      Customer Name      Segment           City  \
# 0        RH-19495        Rick Hansen     Consumer  New York City
# ...

# %%
data[data['State']=='New York']
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298  CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 36      36423  CA-2011-160766 2011-09-14 2011-09-14        Same Day
# 50      40046  US-2012-163825 2012-06-16 2012-06-19     First Class
# 61      39501  CA-2012-114811 2012-11-08 2012-11-08        Same Day
# 121     37923  CA-2011-145541 2011-12-14 2011-12-21  Standard Class
# ...       ...             ...        ...        ...             ...
# 51165   32881  CA-2012-131338 2012-08-09 2012-08-12     First Class
# 51169   37468  CA-2013-141523 2013-12-20 2013-12-25    Second Class
# 51188   32788  CA-2014-166436 2014-11-25 2014-11-29  Standard Class
# 51211   38308  US-2011-135881 2011-05-23 2011-05-27  Standard Class
# 51268   34657  US-2012-142020 2012-06-04 2012-06-08    Second Class
#
#       Customer ID     Customer Name      Segment           City     State  \
# 0        RH-19495       Rick Hansen     Consumer  New York City  New York
# ...

# %% [markdown]
# # To Remove duplicate items of particular column/row

# %%
data.drop_duplicates('Row ID' , inplace=True)  #removes the entire row, not just the Row ID value. inplace = true or we can reassign that also.

print("duplicates deleted")
# Out:
# duplicates deleted

# %%
data
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %% [markdown]
# # loc() function helps to find the data index wise

# %%
data.iloc[3]
# Out:
# Row ID                                     13524
# Order ID                         ES-2013-1579342
# Order Date                   2013-01-28 00:00:00
# Ship Date                    2013-01-30 00:00:00
# Ship Mode                            First Class
# Customer ID                             KM-16375
# Customer Name                   Katherine Murray
# Segment                              Home Office
# City                                      Berlin
# State                                     Berlin
# Country                                  Germany
# Postal Code                                  NaN
# Market                                        EU
# Region                                   Central
# Product ID                       TEC-PH-10004583
# Category                              Technology
# Sub-Category                              Phones
# Product Name      Motorola Smart Phone, Cordless
# Sales                                    2892.51
# ...

# %%
data['Postal Code']
# Out:
# 0        10024.0
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 51285        NaN
# 51286    77095.0
# 51287    93030.0
# 51288        NaN
# 51289        NaN
# Name: Postal Code, Length: 51290, dtype: float64

# %%
data['Postal Code'].dropna()
# Out:
# 0        10024.0
# 8        95823.0
# 9        28027.0
# 10       22304.0
# 16       42420.0
#           ...
# 51270    98103.0
# 51276    77506.0
# 51277    92037.0
# 51286    77095.0
# 51287    93030.0
# Name: Postal Code, Length: 9994, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
data.fillna({'Pin Code':1111}, inplace=True)

# %%
data['Postal Code'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 51290 entries, 0 to 51289
# Series name: Postal Code
# Non-Null Count  Dtype
# --------------  -----
# 51290 non-null  float64
# dtypes: float64(1)
# memory usage: 801.4 KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     51290 non-null  float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %% [markdown]
# # Rename the column name

# %%
data=data.rename(columns={'Postal Code' : 'Pin Code' } ) #data.rename(columns={'Postal Code' : 'Pin Code'}, inplace= True) we can also use this

# %%
data
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %% [markdown]
# # Converting excel file to csv

# %%
data.to_csv('ECOMM DATA.csv')

# %%
data
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
data['Postal Code'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 51290 entries, 0 to 51289
# Series name: Postal Code
# Non-Null Count  Dtype
# --------------  -----
# 9994 non-null   float64
# dtypes: float64(1)
# memory usage: 801.4 KB

# %%
data['Pin Code']=data['Pin Code'].astype(int)

# %%
data['Pin Code'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 51290 entries, 0 to 51289
# Series name: Pin Code
# Non-Null Count  Dtype
# --------------  -----
# 51290 non-null  int64
# dtypes: int64(1)
# memory usage: 801.4 KB

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Pin Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
data['new column']=11

# %%
data
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
len(data)
# Out:
# 51290

# %%
data.drop('new column' , axis=1 , inplace=True)

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Pin Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
data
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
data.sort_values(by='Country')
# Out:
#        Row ID       Order ID Order Date  Ship Date       Ship Mode  \
# 37715   25233  ID-2012-66055 2012-12-16 2012-12-20  Standard Class
# 27075   29095  IN-2012-25476 2012-09-28 2012-10-04  Standard Class
# 8014    29096  IN-2012-25476 2012-09-28 2012-10-04  Standard Class
# 27769   29584  IN-2012-38958 2012-06-05 2012-06-10  Standard Class
# 32746   24406  IN-2013-10622 2013-12-24 2013-12-29  Standard Class
# ...       ...            ...        ...        ...             ...
# 51173   42070   ZI-2014-7610 2014-03-24 2014-03-28  Standard Class
# 39217   42929   ZI-2012-4330 2012-06-04 2012-06-07    Second Class
# 33140   50678   ZI-2014-4230 2014-11-03 2014-11-10  Standard Class
# 20996   44670   ZI-2012-2500 2012-04-06 2012-04-09     First Class
# 45725   42928   ZI-2012-4330 2012-06-04 2012-06-07    Second Class
#
#       Customer ID     Customer Name    Segment         City     State  \
# 37715    SS-20140  Saphhira Shifley  Corporate        Kabul     Kabul
# ...

# %%
data
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...
