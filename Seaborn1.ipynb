# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'name':['Arjun', 'Arun', 'Keshav'], 'age':[23,31,25], 'country':['India', 'Canada', 'France']})
df
# Out:
#      name  age country
# 0   Arjun   23   India
# 1    Arun   31  Canada
# 2  Keshav   25  France

# %%
sns.barplot(x="age" , y="country" , data=df)
# Out:
# <Axes: xlabel='age', ylabel='country'>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tits=sns.load_dataset("titanic")
tits
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.lineplot(x='sex' , y='alive' , data=tits)
# Out:
# <Axes: xlabel='sex', ylabel='alive'>

# %%
d2=sns.load_dataset("tips")

# %%
d2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x="total_bill" , y="tip" , hue="sex" , marker="*" , data=d2)
plt.xlabel("Total_bill")
plt.ylabel
# Out:
# Text(0.5, 0, 'Total_bill')

# %%
#import matplotlib.pyplot as plt

# Define pure Python lists
# years = [2021, 2022, 2023, 2024, 2025]
# growth = [12.5, 14.2, 18.1, 17.9, 22.4]

# # Pass the lists directly to Matplotlib
# plt.plot(years, growth)


#This is in matplot



# import seaborn as sns
# import matplotlib.pyplot as plt

# # Define pure Python lists
# years = [2021, 2022, 2023, 2024, 2025]
# growth = [12.5, 14.2, 18.1, 17.9, 22.4]

# # Pass the lists directly
# sns.lineplot(x=years, y=growth)
# plt.show()


# This is in Seaborn
